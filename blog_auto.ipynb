# %%
import json
import time
import requests
import os
import re
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi
import pyperclip

from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver import ActionChains
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.alert import Alert
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import TimeoutException, NoSuchElementException

from seleniumbase import Driver

from webdriver_manager.chrome import ChromeDriverManager
import undetected_chromedriver as uc
from undetected_chromedriver.options import ChromeOptions

# MongoDB 연결
uri = "mongodb+srv://admin:admin12341234@cluster0.3e37l.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"
# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

db = client['tistory']

# 'posts' 컬렉션을 지정
postsDB = db['posts']

print("Connected to MongoDB")

# 만약에 ChromeDriverManager를 install 해야 할 상황이 오면 아래의 옵션으로 인스톨 한번 해준 후 다시 주석처리 해주기
# options = ChromeOptions()
# options.add_argument(r"user-data-dir=C:\\selenium_data\\Chrome")
# driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)

# 역사 썰
history_story = ['category-item-1201184', 'https://chatgpt.com/g/g-GB6qPTSIt-yeogsa-sseol-blog-json']
science_story = ['category-item-1201410', 'https://chatgpt.com/g/g-G6PYOE1TE-gwahag-sseol-blog-json']
health_story = ['category-item-1204403', 'https://chatgpt.com/g/g-cEdBDA8JR-geongang-gwanryeon-sseol-json']

postings = [history_story, science_story, health_story]
posting = history_story

# driver = uc.Chrome(service=Service(ChromeDriverManager().install()), user_data_dir='C:\\selenium_data\\Chrome', port=54806, disable_logging=True, detach=True, excludeSwitches=["enable-logging"])
driver = Driver(uc=True, user_data_dir='C:\\selenium_data\\Chrome', port=54806)
driver.get("https://www.google.com")

def write_tistory_post(title, content, keywords):
    def get_recent_file_path():
        files_path = r".\\downloaded_files"
        # files_path = r"C:\Users\Jinyo3090\Downloads"

        file_name_and_time_lst = []
        # 해당 경로에 있는 파일들의 생성시간을 함께 리스트로 넣어줌. 
        for f_name in os.listdir(f"{files_path}"):
            written_time = os.path.getctime(f"{files_path}\\{f_name}")
            file_name_and_time_lst.append((f_name, written_time))
        # 생성시간 역순으로 정렬하고, 
        sorted_file_lst = sorted(file_name_and_time_lst, key=lambda x: x[1], reverse=True)
        # 가장 앞에 이는 놈을 넣어준다.
        recent_file = sorted_file_lst[0]
        recent_file_name = recent_file[0]

        return os.path.abspath(f"{files_path}\\{recent_file_name}")
    # tistory_driver = uc.Chrome(user_data_dir='C:\\selenium_data\\Chrome', port=54806)
    tistory_driver = driver
    # 셀레니움으로 티스토리 포스팅 url로 넘어가기
    tistory_driver.implicitly_wait(4)
    tistory_driver.get("https://dropdrop.tistory.com/manage/posts")
    tistory_driver.implicitly_wait(10)
    
    # 로그인 창으로 넘어갈 경우 로그인하기
    try :
        login_button = tistory_driver.find_element(By.CLASS_NAME, "btn_login")
        ActionChains(tistory_driver).click(login_button).perform()
        tistory_driver.implicitly_wait(10)

        id_input = tistory_driver.find_element(By.NAME, "loginId")
        pw_input = tistory_driver.find_element(By.NAME, "password")

        ActionChains(tistory_driver).send_keys_to_element(id_input, "solomoj94@naver.com").perform()
        tistory_driver.implicitly_wait(1)
        ActionChains(tistory_driver).send_keys_to_element(pw_input, "skfrosla131").perform()
        tistory_driver.implicitly_wait(1)

        login_button = tistory_driver.find_element(By.CLASS_NAME, "submit")
        ActionChains(tistory_driver).click(login_button).perform()
        tistory_driver.implicitly_wait(4)
    except NoSuchElementException as e :
        print("이미 로그인 되어 있습니다.")
        # 로그인 되어 있는 경우에는 계정 버튼을 눌러서 들어가기
        try :
            time.sleep(1)
            account_button = tistory_driver.find_element(By.CLASS_NAME, "wrap_profile")
            ActionChains(tistory_driver).click(account_button).perform()
            tistory_driver.implicitly_wait(4)
        except Exception as e:
            print(f"An error occurred: {e}")
    except Exception as e:
        print(f"An error occurred: {e}")

    time.sleep(3)
    # 글 쓰기 버튼 클릭하기
    write_button = tistory_driver.find_element(By.CLASS_NAME, "link_write")
    ActionChains(tistory_driver).click(write_button).perform()
    tistory_driver.implicitly_wait(10)

    # 혹시나 임시저장글 어쩌고가 나올 때를 대비해서
    try :
        alert_present = WebDriverWait(tistory_driver, 5).until(EC.alert_is_present())
        if alert_present:
            tistory_alert = Alert(tistory_driver)
            tistory_alert.dismiss()
            tistory_driver.implicitly_wait(1)
    except TimeoutException as e :
        print("임시저장글 어쩌고가 나오지 않았습니다.")
    except Exception as e:
        print(f"An error occurred: {e}")

    # 글 카테고리 선택하기
    category_button = tistory_driver.find_element(By.ID, "category-btn")
    ActionChains(tistory_driver).click(category_button).perform()
    tistory_driver.implicitly_wait(10)
    # 역사시간 순삭 카테고리
    science_category_list_btn = tistory_driver.find_element(By.ID, posting[0])
    ActionChains(tistory_driver).click(science_category_list_btn).perform()
    tistory_driver.implicitly_wait(1)

    # 글 입력 형식 바꾸기
    category_button = tistory_driver.find_element(By.ID, "editor-mode-layer-btn-open")
    ActionChains(tistory_driver).click(category_button).perform()
    tistory_driver.implicitly_wait(10)
    # HTML 형식으로 바꾸기
    science_category_list_btn = tistory_driver.find_element(By.ID, 'editor-mode-html')
    ActionChains(tistory_driver).click(science_category_list_btn).perform()
    tistory_driver.implicitly_wait(1)
    # 경고창이 뜨면 확인 버튼 누르기
    alert_present = WebDriverWait(tistory_driver, 5).until(EC.alert_is_present())
    if alert_present:
        tistory_alert = Alert(tistory_driver)
        tistory_alert.accept()
        tistory_driver.implicitly_wait(1)

    #글 제목 입력하기
    title_input = tistory_driver.find_element(By.CLASS_NAME, "textarea_tit")
    ActionChains(tistory_driver).send_keys_to_element(title_input, title).perform()
    tistory_driver.implicitly_wait(1)

    # 사진 업로드 할 공간 만들어주기 (글 내용 입력 클릭시에 안눌리게)
    content_input = tistory_driver.find_element(By.CLASS_NAME, "mce-edit-area")
    ActionChains(tistory_driver).click(content_input).perform()
    ActionChains(tistory_driver).send_keys(Keys.ENTER).send_keys(Keys.ENTER).send_keys(Keys.ARROW_UP).send_keys(Keys.ARROW_UP).perform()
    tistory_driver.implicitly_wait(3)

    #사진 업로드하기
    attach_layer_button = tistory_driver.find_element(By.ID, "attach-layer-btn")
    ActionChains(tistory_driver).click(attach_layer_button).perform()
    tistory_driver.implicitly_wait(1)
    image_input = tistory_driver.find_element(By.ID, "attach-image")
    image_input.send_keys(get_recent_file_path())
    tistory_driver.implicitly_wait(1)
    time.sleep(3)
    
    #글 내용 입력하기 (HTML)
    #클립보드에 content 복사
    pyperclip.copy(content)
    content_input = tistory_driver.find_element(By.CLASS_NAME, "mce-edit-area")
    ActionChains(tistory_driver).click(content_input).perform()
    ActionChains(tistory_driver).key_down(Keys.CONTROL).send_keys('v').key_up(Keys.CONTROL).perform()
    tistory_driver.implicitly_wait(10)

    #태그 내용 입력하기
    tag_input = tistory_driver.find_element(By.ID, "tagText")
    if (type(keywords) == type([])) :
        keywords = ", ".join(map(str, keywords))
    ActionChains(driver).send_keys_to_element(tag_input, keywords).perform()
    tistory_driver.implicitly_wait(1)
    

    
    # 글 입력 형식 바꾸기
    category_button = tistory_driver.find_element(By.XPATH, "//*[@id='html-editor-container']/div[1]/div/div/div/div/div/div[5]/div/div/button")
    ActionChains(tistory_driver).click(category_button).perform()
    tistory_driver.implicitly_wait(10)
    time.sleep(1)

    # 기본 형식으로 바꾸기 (대표 이미지 자동 설정을 위해)
    science_category_list_btn = tistory_driver.find_element(By.ID, 'editor-mode-kakao-tistory')
    ActionChains(tistory_driver).click(science_category_list_btn).perform()
    tistory_driver.implicitly_wait(1)
    time.sleep(1)
    # 경고창이 뜨면 확인 버튼 누르기
    alert_present = WebDriverWait(tistory_driver, 5).until(EC.alert_is_present())
    if alert_present:
        tistory_alert = Alert(tistory_driver)
        tistory_alert.accept()
        tistory_driver.implicitly_wait(1)
        
    time.sleep(3)

    #완료 버튼 누르기
    publish_layer_button = tistory_driver.find_element(By.ID, "publish-layer-btn")
    ActionChains(tistory_driver).click(publish_layer_button).perform()
    tistory_driver.implicitly_wait(1)

    time.sleep(3)

    # 공개 버튼 누르기 (티스토리 기본 설정에서 변경 가능)
    # public_button = tistory_driver.find_element(By.XPATH, "//*[@id='editor-root']/div[5]/div/div/div/form/fieldset/div[2]/div/dl[1]/dd/div[1]")
    # ActionChains(tistory_driver).click(public_button).perform()
    # tistory_driver.implicitly_wait(1)
    # public_button = tistory_driver.find_element(By.XPATH, "//*[@id='editor-root']/div[5]/div/div/div/form/fieldset/div[2]/div/dl[1]/dd/div[1]")
    # ActionChains(tistory_driver).click(public_button).perform()
    # tistory_driver.implicitly_wait(1)

    # 대표이미지 설정하기 안됨..
    # image_input = tistory_driver.find_element(By.CLASS_NAME, "inp_g")
    # image_input.send_keys(get_recent_file_path())
    # tistory_driver.implicitly_wait(2)

    # #발행 버튼 누르기
    publish_button = tistory_driver.find_element(By.ID, "publish-btn")
    ActionChains(tistory_driver).click(publish_button).perform()
    tistory_driver.implicitly_wait(1)

    time.sleep(2)

    # DB에 저장하기
    postsDB.insert_one({"title":title, "category": posting[0], "created_at": time.time()})
    
    

def get_post_from_gpt():
    
    def replace_markdown_bold_with_html(text):
        # 정규식 패턴: **로 감싸진 문자열 찾기
        pattern = r"\*\*(.*?)\*\*"
        
        # 매치된 문자열을 <b> </b>로 감싸는 함수
        def replace_with_bold(match):
            return f"<b>{match.group(1)}</b>"
        
        # 전체 텍스트에서 패턴에 매치되는 모든 부분을 찾아 replace_with_bold 함수로 변환
        return re.sub(pattern, replace_with_bold, text)

        
    chatgpt_driver = driver
    chatgpt_driver.implicitly_wait(4)
    chatgpt_driver.get(posting[1])
    chatgpt_driver.implicitly_wait(10)
    time.sleep(5)

    results = postsDB.find({"category": posting[0]})
    names = [result["title"] for result in results]

    gpt_chat_input = chatgpt_driver.find_element(By.ID, "prompt-textarea")
    ActionChains(chatgpt_driver).send_keys_to_element(gpt_chat_input, "Create new content while avoiding following listings as much as possible. [" + ", ".join(map(str,names)) + "]").perform()
    gpt_chat_input.send_keys(Keys.ENTER)
    time.sleep(1)
    # WebDriverWait(chatgpt_driver, 80).until(EC.presence_of_element_located((By.CSS_SELECTOR, "[aria-label='프롬프트 보내기']")))
    WebDriverWait(chatgpt_driver, 80).until(EC.presence_of_element_located((By.CSS_SELECTOR, "[aria-label='음성 모드 시작']")))
    # gpt_chat_output_element = chatgpt_driver.find_element(By.XPATH, "/html/body/div[1]/div[2]/main/div[1]/div[1]/div/div/div/div/article[2]/div/div/div[2]/div/div[1]/div/div/div/p")
    # gpt_chat_output_json_text = gpt_chat_output_element.text
    # gpt_chat_output_dict = json.loads(gpt_chat_output_json_text)


    gpt_chat_output_element = driver.find_element(By.TAG_NAME, 'code')
    # <code> 태그 내부의 모든 <span> 태그들 찾기
    span_elements = gpt_chat_output_element.find_elements(By.TAG_NAME, 'span')
    # <span> 태그들의 텍스트를 하나의 문자열로 조합
    gpt_chat_output_json_text = ''.join([replace_markdown_bold_with_html(span.text) for span in span_elements])
    gpt_chat_output_dict = json.loads(gpt_chat_output_json_text)

    gpt_chat_input = chatgpt_driver.find_element(By.ID, "prompt-textarea")
    ActionChains(chatgpt_driver).send_keys_to_element(gpt_chat_input, "위 내용의 커버사진으로 쓸만한 이미지 정책에 걸리지 않게 하나 만들어 줘").perform()
    gpt_chat_input.send_keys(Keys.ENTER)
    time.sleep(25)
    images = chatgpt_driver.find_elements(By.TAG_NAME, "img")
    last_image = images[-1]
    ActionChains(chatgpt_driver).click(last_image).perform()

    chatgpt_driver.implicitly_wait(5)
    gpt_img_download_element = chatgpt_driver.find_element(By.XPATH, "/html/body/div[4]/div/div[2]/div[1]/div/div[1]/div[2]/span[2]/button")
    ActionChains(chatgpt_driver).click(gpt_img_download_element).perform()

    time.sleep(5)

    return gpt_chat_output_dict

def main_process():
    gpt_chat_output_dict = get_post_from_gpt()
    print(gpt_chat_output_dict)
    write_tistory_post(gpt_chat_output_dict['title'], gpt_chat_output_dict['content'], gpt_chat_output_dict['keywords'])

for _posting in postings:
    posting = _posting
    for i in range(5):
        try:
            main_process()
        except Exception as e:
            print(f"An error occurred: {e}")
            continue
# Out:
# Connected to MongoDB
# {'title': '고대 카파도키아의 숨겨진 도시와 초기 기독교의 피난처', 'content': '<h2>신비로운 도시, 카파도키아의 비밀스러운 역사</h2><br/>터키의 중심부에 자리 잡은 카파도키아는 신비로운 지형과 경이로운 동굴 주거지로 잘 알려져 있습니다. 이 지역은 약 4세기경 초기 기독교인들이 박해를 피해 은신처로 삼은 장소로, 수천 개의 숨겨진 동굴과 비밀 통로로 이루어진 거대한 지하 도시들이 존재합니다. 대표적인 지하 도시는 데린쿠유와 카이막르로, 이곳은 수천 명이 동시에 거주할 수 있을 만큼 거대한 규모를 자랑합니다.<br/><br/><h2>데린쿠유와 카이막르 지하 도시의 발견</h2><br/>1963년, 한 터키 농부가 집에서 벽을 허물다 뜻밖에 지하 도시의 입구를 발견한 후, 이 지하 도시는 세상에 모습을 드러내게 되었습니다. 발굴된 데린쿠유 지하 도시는 약 18층 규모로, 인구 약 2만 명이 동시에 생활할 수 있었던 곳으로 추정됩니다. 이곳에는 방, 부엌, 창고, 교회, 학교 등 필요한 모든 시설이 갖춰져 있었으며, 심지어 포도주 저장고와 동물 축사까지 있었습니다. 이 지역은 내부에서 바깥의 공기를 유입할 수 있도록 설계된 환기 시스템이 존재해 지금도 그 공학적 지혜에 감탄을 자아내고 있습니다.<br/><br/><h3>카이막르 지하 도시의 세부 구조와 방어 시스템</h3><br/>카이막르 지하 도시는 데린쿠유에 비해 작지만, 매우 정교하게 설계되었습니다. 특히 이곳은 복잡한 미로 형태로 되어 있어 침입자들이 방향을 잃기 쉽게 설계된 점이 독특합니다. 각 층에는 철문 같은 큰 돌문이 설치되어 적의 접근을 차단했으며, 이러한 방어 시스템은 당시 주민들이 외부 침입자로부터 안전하게 생활할 수 있게 했습니다.<br/><br/><h2>초기 기독교인들의 피난처, 카파도키아</h2><br/>카파도키아는 4세기경 로마 제국의 기독교 박해를 피해 이곳으로 모여든 초기 기독교인들에게는 이상적인 피난처였습니다. 그들은 카파도키아의 지형을 활용해 거대한 지하 도시를 건설하였으며, 이 도시들은 서로 연결된 통로를 통해 연결되어 있었습니다. 이들은 동굴 교회를 설립하고, 비밀 예배를 드리며 기독교 신앙을 지켰습니다. 오늘날까지도 남아있는 벽화들에는 예수와 성자들의 모습이 남아 있어 당시의 신앙 생활을 엿볼 수 있게 합니다.<br/><br/><h2>지하 도시의 생활과 문화</h2><br/>지하 도시에 거주했던 사람들은 단순히 피신한 것뿐만 아니라 일상 생활을 영위하며 나름의 문화를 발전시켰습니다. 특히 카파도키아 지역에서는 포도 농업이 발전했으며, 이를 통해 와인을 만들어 축제나 종교 의식에 사용하였습니다. 또한, 이 지역에서 주로 사용되었던 고대 언어인 시리아어의 흔적도 남아 있어 다양한 문화가 공존했음을 알 수 있습니다.<br/><br/><h3>카파도키아의 지하 교회와 벽화</h3><br/>카파도키아의 지하 도시에는 수많은 교회가 존재하며, 특히 벽화들에는 초기 기독교 미술의 흔적이 남아 있습니다. 생명을 위협받으면서도 신앙을 지키기 위해 모였던 이들의 마음이 벽화 속에 표현된 모습은 진지하고 경건합니다. 교회 벽화에는 예수의 생애와 성인들의 이야기가 담겨 있으며, 이는 당시 박해를 피해 숨어 지내던 기독교인들에게 큰 위로와 신념의 상징이 되었습니다.<br/><br/><h2>지하 도시의 비밀과 미스터리</h2><br/>오늘날까지도 이 지하 도시들은 그들이 언제, 어떻게 만들어졌는지에 대해 확실히 밝혀지지 않은 부분이 많습니다. 일부 학자들은 이러한 지하 도시들이 기독교 박해 이전에 이미 건설되어 있었다고 주장하며, 초기 히타이트나 프리지아인들의 작품일 가능성을 제기하기도 합니다. 또한, 이 거대한 도시가 어떤 방식으로 건설되었는지에 대한 미스터리도 여전합니다. 다수의 인력이 필요했을 터인데, 당시 기술로는 어떻게 수십 층에 이르는 구조물을 뚫고 유지했는지가 학자들의 연구 과제로 남아 있습니다.<br/><br/><h2>카파도키아의 현재와 역사적 가치</h2><br/>카파도키아의 지하 도시들은 유네스코 세계문화유산에 등재되어 있으며, 매년 수많은 관광객이 방문하는 중요한 역사적 명소가 되었습니다. 하지만 그 중 일부는 아직도 발굴되지 않은 상태로 남아 있어 앞으로도 새로운 비밀들이 밝혀질 가능성이 큽니다. 카파도키아의 이러한 유산들은 인류가 박해 속에서도 신념과 문화를 지켜온 역사를 생생히 보여주는 상징적 장소라 할 수 있습니다.<br/><br/>', 'keywords': '카파도키아, 데린쿠유, 카이막르, 지하 도시, 초기 기독교, 박해, 터키 역사, 벽화, 카파도키아 피난처'}
# 임시저장글 어쩌고가 나오지 않았습니다.
# An error occurred: Message: no such element: Unable to locate element: {"method":"tag name","selector":"code"}
#   (Session info: chrome=130.0.6723.70); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF7A8743AB5+28005]
# 	(No symbol) [0x00007FF7A86A83B0]
# 	(No symbol) [0x00007FF7A854580A]
# 	(No symbol) [0x00007FF7A8595A3E]
# 	(No symbol) [0x00007FF7A8595D2C]
# 	(No symbol) [0x00007FF7A85DEA97]
# 	(No symbol) [0x00007FF7A85BBA7F]
# 	(No symbol) [0x00007FF7A85DB8B3]
# 	(No symbol) [0x00007FF7A85BB7E3]
# 	(No symbol) [0x00007FF7A85875C8]
# 	(No symbol) [0x00007FF7A8588731]
# 	GetHandleVerifier [0x00007FF7A8A3643D+3118829]
# 	GetHandleVerifier [0x00007FF7A8A86C90+3448640]
# 	GetHandleVerifier [0x00007FF7A8A7CF0D+3408317]
# 	GetHandleVerifier [0x00007FF7A880A40B+841403]
# 	(No symbol) [0x00007FF7A86B340F]
# 	(No symbol) [0x00007FF7A86AF484]
# 	(No symbol) [0x00007FF7A86AF61D]
# 	(No symbol) [0x00007FF7A869EB79]
# 	BaseThreadInitThunk [0x00007FFCF26053E0+16]
# 	RtlUserThreadStart [0x00007FFCF302485B+43]
#
# An error occurred: Message:
# Stacktrace:
# 	GetHandleVerifier [0x00007FF7A8743AB5+28005]
# 	(No symbol) [0x00007FF7A86A83B0]
# 	(No symbol) [0x00007FF7A854580A]
# 	(No symbol) [0x00007FF7A8595A3E]
# 	(No symbol) [0x00007FF7A8595D2C]
# 	(No symbol) [0x00007FF7A85DEA97]
# 	(No symbol) [0x00007FF7A85BBA7F]
# 	(No symbol) [0x00007FF7A85DB8B3]
# 	(No symbol) [0x00007FF7A85BB7E3]
# 	(No symbol) [0x00007FF7A85875C8]
# 	(No symbol) [0x00007FF7A8588731]
# 	GetHandleVerifier [0x00007FF7A8A3643D+3118829]
# 	GetHandleVerifier [0x00007FF7A8A86C90+3448640]
# 	GetHandleVerifier [0x00007FF7A8A7CF0D+3408317]
# 	GetHandleVerifier [0x00007FF7A880A40B+841403]
# 	(No symbol) [0x00007FF7A86B340F]
# 	(No symbol) [0x00007FF7A86AF484]
# 	(No symbol) [0x00007FF7A86AF61D]
# 	(No symbol) [0x00007FF7A869EB79]
# 	BaseThreadInitThunk [0x00007FFCF26053E0+16]
# 	RtlUserThreadStart [0x00007FFCF302485B+43]
#
# {'title': '세계를 지배한 아바르족의 비밀과 유산', 'content': '<h2>유럽을 뒤흔든 미지의 전사, 아바르족</h2><br/>유럽 역사 속에서 가장 강력하면서도 신비로운 유목 민족을 꼽으라면 <b>아바르족</b>이 빠지지 않는다. 6세기 중반, 동유럽을 중심으로 급부상한 아바르족은 동로마 제국과 프랑크 왕국을 위협하며 막강한 세력을 과시했다. 오늘날 헝가리, 오스트리아, 루마니아 등지에 걸친 아바르 카간국은 강력한 군사력과 효율적인 관리 체계로 유럽 사회와 군사 전략에 큰 영향을 미쳤다.<br/><br/><h3>기원과 대이동: 스텝 지대에서 유럽으로</h3><br/>아바르족의 기원은 여전히 논쟁의 여지가 있다. 학자들은 아바르족이 중앙아시아 스텝 지대에서 왔다고 추정하지만, 그들의 언어와 문화는 유럽에 들어온 후 다른 부족과 섞이며 <b>복합적 문화</b>를 형성했다. 특히 아바르족은 고대 몽골 및 투르크계 유목 민족과 밀접한 연관이 있는 것으로 보인다. 5세기 말과 6세기 초, 이들은 <b>유럽으로 대규모 이동</b>을 시작하며 당시 동유럽을 지배하던 다른 유목 민족들과 경쟁 관계에 들어섰다.<br/><br/><h3>아바르 카간국의 번영과 군사력</h3><br/>6세기 후반, 아바르족은 헝가리를 중심으로 <b>아바르 카간국</b>을 세웠다. 이 카간국은 동로마 제국을 공략하며 명성을 쌓았다. 아바르 군대는 독특한 전술을 통해 대규모 전투에서도 우위를 점했다. <b>말을 이용한 기병전</b>에서 뛰어난 실력을 발휘했으며, 그들의 금속 무기는 동로마 제국에도 영향을 끼쳤다. 또한, 아바르 카간국은 철저한 <b>군사 위계와 귀족 제도</b>를 통해 전사들의 충성을 유지하며 강력한 통제력을 과시했다.<br/><br/><h3>동로마와의 충돌, 그리고 콘스탄티노플 공략</h3><br/>7세기, 아바르족은 동로마 제국의 수도 <b>콘스탄티노플을 공략</b>하는 대담한 계획을 세웠다. 626년, 아바르족은 사산 제국과 동맹을 맺고 콘스탄티노플을 포위하며 전 유럽에 충격을 주었다. 그들은 견고한 성벽을 돌파하지는 못했으나, 이 사건은 동로마 제국과 유럽 전역에 아바르의 군사적 위협을 각인시켰다. 포위전 후, 아바르족은 더욱 강력한 군사력을 구축하여 동유럽 일대를 영향력 아래에 두었다.<br/><br/><h3>문화적 유산과 경제적 번영</h3><br/>아바르 카간국은 단순히 군사적 강국만이 아니었다. 이들은 스텝 지역과 동유럽을 연결하는 <b>상업 루트</b>를 통해 경제적 번영을 이뤘다. 특히, 아바르족은 <b>귀금속 가공 기술</b>로 유명했으며, 그들의 금속 공예품은 당시 유럽과 아시아의 여러 문화에 영향을 미쳤다. 아바르족이 만든 금속 장식과 무기들은 동유럽 여러 지역에서 발견되며, 고도의 금속 가공 기술을 입증하고 있다.<br/><br/><h3>쇠퇴와 멸망: 프랑크 왕국의 공격</h3><br/>아바르 카간국의 쇠퇴는 8세기 후반에 찾아왔다. <b>프랑크 왕국의 샤를마뉴 대제</b>가 동유럽으로 확장을 시작하며 아바르족과의 갈등이 고조되었다. 796년, 샤를마뉴의 대대적인 군사 작전으로 아바르 카간국은 결정적인 타격을 받았다. 연이은 전투 끝에 아바르족은 패배하고, 그들의 영토는 프랑크 왕국의 지배 아래로 넘어갔다. 아바르족의 멸망은 중앙아시아 출신 유목 민족의 유럽 정복 시대의 막을 내리는 사건으로 기록된다.<br/><br/><h3>아바르족의 흔적과 고고학적 발견</h3><br/>현대에 들어 아바르족의 유산은 헝가리와 동유럽 여러 지역에서 고고학적 발굴을 통해 새롭게 주목받고 있다. 아바르족의 무덤과 유물들은 그들의 생활 방식을 엿볼 수 있게 해주며, 당시 동유럽에서 고도의 문화를 이루었음을 보여준다. 그들의 <b>금속 공예품</b>과 전통적인 유목 생활 흔적은 현대 유럽사 연구에 중요한 자료가 되고 있다.<br/><br/><h3>아바르족이 남긴 영향과 의의</h3><br/>아바르족은 유럽 역사에서 종종 잊혀지지만, 이들의 존재는 동유럽에 큰 영향을 미쳤다. 아바르족의 군사 전술과 조직 체계는 이후 슬라브계 민족들에게 전수되었고, 아바르족이 형성한 무역 루트는 동서 교류의 중요한 기반이 되었다. 이처럼 아바르 카간국은 단순히 강력한 유목 국가에 그치지 않고, 유럽과 아시아의 경계에 선 문명 교류의 상징으로 자리 잡았다.', 'keywords': '아바르족, 동유럽 역사, 유목 민족, 아바르 카간국, 콘스탄티노플 포위, 샤를마뉴 대제, 동로마 제국, 헝가리 역사, 금속 공예, 유럽의 유목민'}
# 이미 로그인 되어 있습니다.
# An error occurred: Message: no such element: Unable to locate element: {"method":"css selector","selector":".wrap_profile"}
#   (Session info: chrome=130.0.6723.70); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF7A8743AB5+28005]
# 	(No symbol) [0x00007FF7A86A83B0]
# 	(No symbol) [0x00007FF7A854580A]
# 	(No symbol) [0x00007FF7A8595A3E]
# 	(No symbol) [0x00007FF7A8595D2C]
# 	(No symbol) [0x00007FF7A85DEA97]
# 	(No symbol) [0x00007FF7A85BBA7F]
# 	(No symbol) [0x00007FF7A85DB8B3]
# 	(No symbol) [0x00007FF7A85BB7E3]
# 	(No symbol) [0x00007FF7A85875C8]
# 	(No symbol) [0x00007FF7A8588731]
# 	GetHandleVerifier [0x00007FF7A8A3643D+3118829]
# 	GetHandleVerifier [0x00007FF7A8A86C90+3448640]
# 	GetHandleVerifier [0x00007FF7A8A7CF0D+3408317]
# 	GetHandleVerifier [0x00007FF7A880A40B+841403]
# 	(No symbol) [0x00007FF7A86B340F]
# 	(No symbol) [0x00007FF7A86AF484]
# 	(No symbol) [0x00007FF7A86AF61D]
# 	(No symbol) [0x00007FF7A869EB79]
# 	BaseThreadInitThunk [0x00007FFCF26053E0+16]
# 	RtlUserThreadStart [0x00007FFCF302485B+43]
#
# 임시저장글 어쩌고가 나오지 않았습니다.
# An error occurred: Message: no such element: Unable to locate element: {"method":"tag name","selector":"code"}
#   (Session info: chrome=130.0.6723.70); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF7A8743AB5+28005]
# 	(No symbol) [0x00007FF7A86A83B0]
# 	(No symbol) [0x00007FF7A854580A]
# 	(No symbol) [0x00007FF7A8595A3E]
# 	(No symbol) [0x00007FF7A8595D2C]
# 	(No symbol) [0x00007FF7A85DEA97]
# 	(No symbol) [0x00007FF7A85BBA7F]
# 	(No symbol) [0x00007FF7A85DB8B3]
# 	(No symbol) [0x00007FF7A85BB7E3]
# 	(No symbol) [0x00007FF7A85875C8]
# 	(No symbol) [0x00007FF7A8588731]
# 	GetHandleVerifier [0x00007FF7A8A3643D+3118829]
# 	GetHandleVerifier [0x00007FF7A8A86C90+3448640]
# 	GetHandleVerifier [0x00007FF7A8A7CF0D+3408317]
# 	GetHandleVerifier [0x00007FF7A880A40B+841403]
# 	(No symbol) [0x00007FF7A86B340F]
# 	(No symbol) [0x00007FF7A86AF484]
# 	(No symbol) [0x00007FF7A86AF61D]
# 	(No symbol) [0x00007FF7A869EB79]
# 	BaseThreadInitThunk [0x00007FFCF26053E0+16]
# 	RtlUserThreadStart [0x00007FFCF302485B+43]
#
# An error occurred: Message: no such element: Unable to locate element: {"method":"css selector","selector":"[id="prompt-textarea"]"}
#   (Session info: chrome=130.0.6723.70); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF7A8743AB5+28005]
# 	(No symbol) [0x00007FF7A86A83B0]
# 	(No symbol) [0x00007FF7A854580A]
# 	(No symbol) [0x00007FF7A8595A3E]
# 	(No symbol) [0x00007FF7A8595D2C]
# 	(No symbol) [0x00007FF7A85DEA97]
# 	(No symbol) [0x00007FF7A85BBA7F]
# 	(No symbol) [0x00007FF7A85DB8B3]
# 	(No symbol) [0x00007FF7A85BB7E3]
# 	(No symbol) [0x00007FF7A85875C8]
# 	(No symbol) [0x00007FF7A8588731]
# 	GetHandleVerifier [0x00007FF7A8A3643D+3118829]
# 	GetHandleVerifier [0x00007FF7A8A86C90+3448640]
# 	GetHandleVerifier [0x00007FF7A8A7CF0D+3408317]
# 	GetHandleVerifier [0x00007FF7A880A40B+841403]
# 	(No symbol) [0x00007FF7A86B340F]
# 	(No symbol) [0x00007FF7A86AF484]
# 	(No symbol) [0x00007FF7A86AF61D]
# 	(No symbol) [0x00007FF7A869EB79]
# 	BaseThreadInitThunk [0x00007FFCF26053E0+16]
# 	RtlUserThreadStart [0x00007FFCF302485B+43]
#
# An error occurred: Message: no such element: Unable to locate element: {"method":"css selector","selector":"[id="prompt-textarea"]"}
#   (Session info: chrome=130.0.6723.70); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF7A8743AB5+28005]
# 	(No symbol) [0x00007FF7A86A83B0]
# 	(No symbol) [0x00007FF7A854580A]
# 	(No symbol) [0x00007FF7A8595A3E]
# 	(No symbol) [0x00007FF7A8595D2C]
# 	(No symbol) [0x00007FF7A85DEA97]
# 	(No symbol) [0x00007FF7A85BBA7F]
# 	(No symbol) [0x00007FF7A85DB8B3]
# 	(No symbol) [0x00007FF7A85BB7E3]
# 	(No symbol) [0x00007FF7A85875C8]
# 	(No symbol) [0x00007FF7A8588731]
# 	GetHandleVerifier [0x00007FF7A8A3643D+3118829]
# 	GetHandleVerifier [0x00007FF7A8A86C90+3448640]
# 	GetHandleVerifier [0x00007FF7A8A7CF0D+3408317]
# 	GetHandleVerifier [0x00007FF7A880A40B+841403]
# 	(No symbol) [0x00007FF7A86B340F]
# 	(No symbol) [0x00007FF7A86AF484]
# 	(No symbol) [0x00007FF7A86AF61D]
# 	(No symbol) [0x00007FF7A869EB79]
# 	BaseThreadInitThunk [0x00007FFCF26053E0+16]
# 	RtlUserThreadStart [0x00007FFCF302485B+43]
#
# An error occurred: Message: no such element: Unable to locate element: {"method":"css selector","selector":"[id="prompt-textarea"]"}
#   (Session info: chrome=130.0.6723.70); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF7A8743AB5+28005]
# 	(No symbol) [0x00007FF7A86A83B0]
# 	(No symbol) [0x00007FF7A854580A]
# 	(No symbol) [0x00007FF7A8595A3E]
# 	(No symbol) [0x00007FF7A8595D2C]
# 	(No symbol) [0x00007FF7A85DEA97]
# 	(No symbol) [0x00007FF7A85BBA7F]
# 	(No symbol) [0x00007FF7A85DB8B3]
# 	(No symbol) [0x00007FF7A85BB7E3]
# 	(No symbol) [0x00007FF7A85875C8]
# 	(No symbol) [0x00007FF7A8588731]
# 	GetHandleVerifier [0x00007FF7A8A3643D+3118829]
# 	GetHandleVerifier [0x00007FF7A8A86C90+3448640]
# 	GetHandleVerifier [0x00007FF7A8A7CF0D+3408317]
# 	GetHandleVerifier [0x00007FF7A880A40B+841403]
# 	(No symbol) [0x00007FF7A86B340F]
# 	(No symbol) [0x00007FF7A86AF484]
# 	(No symbol) [0x00007FF7A86AF61D]
# 	(No symbol) [0x00007FF7A869EB79]
# 	BaseThreadInitThunk [0x00007FFCF26053E0+16]
# 	RtlUserThreadStart [0x00007FFCF302485B+43]
#
# An error occurred: Message: no such element: Unable to locate element: {"method":"css selector","selector":"[id="prompt-textarea"]"}
#   (Session info: chrome=130.0.6723.70); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF7A8743AB5+28005]
# 	(No symbol) [0x00007FF7A86A83B0]
# 	(No symbol) [0x00007FF7A854580A]
# 	(No symbol) [0x00007FF7A8595A3E]
# 	(No symbol) [0x00007FF7A8595D2C]
# 	(No symbol) [0x00007FF7A85DEA97]
# 	(No symbol) [0x00007FF7A85BBA7F]
# 	(No symbol) [0x00007FF7A85DB8B3]
# 	(No symbol) [0x00007FF7A85BB7E3]
# 	(No symbol) [0x00007FF7A85875C8]
# 	(No symbol) [0x00007FF7A8588731]
# 	GetHandleVerifier [0x00007FF7A8A3643D+3118829]
# 	GetHandleVerifier [0x00007FF7A8A86C90+3448640]
# 	GetHandleVerifier [0x00007FF7A8A7CF0D+3408317]
# 	GetHandleVerifier [0x00007FF7A880A40B+841403]
# 	(No symbol) [0x00007FF7A86B340F]
# 	(No symbol) [0x00007FF7A86AF484]
# 	(No symbol) [0x00007FF7A86AF61D]
# 	(No symbol) [0x00007FF7A869EB79]
# 	BaseThreadInitThunk [0x00007FFCF26053E0+16]
# 	RtlUserThreadStart [0x00007FFCF302485B+43]
#
# An error occurred: Message: no such element: Unable to locate element: {"method":"css selector","selector":"[id="prompt-textarea"]"}
#   (Session info: chrome=130.0.6723.70); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF7A8743AB5+28005]
# 	(No symbol) [0x00007FF7A86A83B0]
# 	(No symbol) [0x00007FF7A854580A]
# 	(No symbol) [0x00007FF7A8595A3E]
# 	(No symbol) [0x00007FF7A8595D2C]
# 	(No symbol) [0x00007FF7A85DEA97]
# 	(No symbol) [0x00007FF7A85BBA7F]
# 	(No symbol) [0x00007FF7A85DB8B3]
# 	(No symbol) [0x00007FF7A85BB7E3]
# 	(No symbol) [0x00007FF7A85875C8]
# 	(No symbol) [0x00007FF7A8588731]
# 	GetHandleVerifier [0x00007FF7A8A3643D+3118829]
# 	GetHandleVerifier [0x00007FF7A8A86C90+3448640]
# 	GetHandleVerifier [0x00007FF7A8A7CF0D+3408317]
# 	GetHandleVerifier [0x00007FF7A880A40B+841403]
# 	(No symbol) [0x00007FF7A86B340F]
# 	(No symbol) [0x00007FF7A86AF484]
# 	(No symbol) [0x00007FF7A86AF61D]
# 	(No symbol) [0x00007FF7A869EB79]
# 	BaseThreadInitThunk [0x00007FFCF26053E0+16]
# 	RtlUserThreadStart [0x00007FFCF302485B+43]
#
# {'title': "면역력과 전신 건강을 위한 '강황 라떼'의 다양한 효능", 'content': '<h2>강황 라떼의 주요 효능과 전신 건강 효과</h2><br/><h3>1. 면역력 강화와 염증 완화</h3><p>강황 라떼는 강황의 주요 성분인 커큐민 덕분에 면역력을 높이는 데 도움을 줍니다. 커큐민은 항염증 특성을 가지고 있어 체내 염증을 줄여주며, 각종 세균 및 바이러스 감염에 저항력을 키워 줍니다. 면역력이 약한 사람이나 계절성 감염에 취약한 경우, 강황 라떼를 꾸준히 마시면 긍정적인 효과를 얻을 수 있습니다.</p><h3>2. 소화 기능 개선</h3><p>강황은 소화 효소 분비를 촉진하여 소화력을 개선하는 데 도움을 줍니다. 강황 라떼는 특히 식후에 마실 경우 소화불량이나 속쓰림을 줄이는 데 효과적입니다. 또한 위산 분비 조절을 통해 소화기관을 보호하고, 소화기 건강을 유지하는 데 유익합니다.</p><h3>3. 심신 안정과 수면 질 개선</h3><p>강황 라떼는 따뜻한 우유와 결합하여 수면을 돕는 진정 효과를 제공합니다. 잠들기 전 한 잔의 강황 라떼는 스트레스 완화와 심신 안정에 기여하여 수면 질을 높이는 데 도움을 줍니다. 우유에 함유된 트립토판 성분과 강황의 항산화 성분이 결합하여 신경을 안정시킵니다.</p><h3>4. 뼈 건강 증진</h3><p>강황 라떼에 들어가는 우유와 같은 유제품은 칼슘 공급원으로써 뼈 건강에 도움을 줍니다. 특히 노년층의 골밀도를 유지하고 뼈 손상을 예방하는 데 효과적입니다. 강황의 항산화 성분은 뼈 건강을 저해하는 산화 스트레스를 줄여주기 때문에 골다공증 예방에도 긍정적인 영향을 줍니다.</p><h3>5. 신체 전반의 항산화 효과</h3><p>강황 라떼에 포함된 강황의 커큐민 성분은 강력한 항산화제로서, 활성산소로 인한 손상을 줄여줍니다. 이로 인해 노화 방지와 피부 건강에도 도움을 주며, 장기적인 체내 염증 완화에도 효과가 있습니다. 커큐민은 뇌세포 손상을 줄여주고 신경계 건강을 지원하여 인지 기능에도 도움을 줄 수 있습니다.</p><br/>', 'keywords': ['강황 라떼', '면역력 강화', '소화 기능 개선', '수면 질 개선', '뼈 건강', '항산화 효과']}
# 이미 로그인 되어 있습니다.
# An error occurred: Message: no such element: Unable to locate element: {"method":"css selector","selector":".wrap_profile"}
#   (Session info: chrome=130.0.6723.70); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF7A8743AB5+28005]
# 	(No symbol) [0x00007FF7A86A83B0]
# 	(No symbol) [0x00007FF7A854580A]
# 	(No symbol) [0x00007FF7A8595A3E]
# 	(No symbol) [0x00007FF7A8595D2C]
# 	(No symbol) [0x00007FF7A85DEA97]
# 	(No symbol) [0x00007FF7A85BBA7F]
# 	(No symbol) [0x00007FF7A85DB8B3]
# 	(No symbol) [0x00007FF7A85BB7E3]
# 	(No symbol) [0x00007FF7A85875C8]
# 	(No symbol) [0x00007FF7A8588731]
# 	GetHandleVerifier [0x00007FF7A8A3643D+3118829]
# 	GetHandleVerifier [0x00007FF7A8A86C90+3448640]
# 	GetHandleVerifier [0x00007FF7A8A7CF0D+3408317]
# 	GetHandleVerifier [0x00007FF7A880A40B+841403]
# 	(No symbol) [0x00007FF7A86B340F]
# 	(No symbol) [0x00007FF7A86AF484]
# 	(No symbol) [0x00007FF7A86AF61D]
# 	(No symbol) [0x00007FF7A869EB79]
# 	BaseThreadInitThunk [0x00007FFCF26053E0+16]
# 	RtlUserThreadStart [0x00007FFCF302485B+43]
#
# 임시저장글 어쩌고가 나오지 않았습니다.
# {'title': '에너지 향상과 소화 건강을 위한 코엔자임 Q10의 효능', 'content': '<h2>코엔자임 Q10이란?</h2> <br/> 코엔자임 Q10(CoQ10)은 우리 몸에서 자연적으로 생성되는 항산화 물질로, 에너지 생성과 세포의 기능을 유지하는 데 중요한 역할을 합니다. 나이가 들수록 체내 CoQ10 농도가 감소할 수 있어 보충제를 통해 건강을 관리하는 사람들이 늘고 있습니다.<br/><br/> <h3>1. 에너지 생성과 피로 회복에 미치는 효과</h3> <br/> CoQ10은 세포의 미토콘드리아에서 에너지를 생성하는 과정에 필수적인 성분으로 작용합니다. 특히 심장과 같은 에너지가 많이 필요한 장기에 충분한 에너지를 제공하여 전반적인 피로 회복과 체력 향상에 도움을 줍니다. 연구에 따르면 CoQ10 보충제는 만성 피로 증후군 환자들에서 피로감을 줄이고 일상 에너지 수준을 증가시키는 데 효과적인 것으로 나타났습니다.<br/><br/> <h3>2. 심혈관 건강에 도움</h3> <br/> CoQ10은 항산화 작용을 통해 세포 손상을 방지하며, 혈관 내 염증을 줄이고 혈압을 안정시키는 데 도움을 줄 수 있습니다. 심혈관 건강이 우려되는 사람들에게 CoQ10 보충은 심장의 기능을 지원하며 심장 질환의 위험을 줄이는 데 도움이 될 수 있습니다. 특히 연구에서는 CoQ10 보충이 심부전 환자의 증상 개선과 전반적인 심장 건강에 긍정적인 영향을 준다고 보고되었습니다.<br/><br/> <h3>3. 노화 방지와 피부 건강 개선</h3> <br/> CoQ10은 강력한 항산화제로서 체내 자유 라디칼을 중화하여 세포 노화를 방지하고, 피부의 탄력과 수분을 유지하는 데 기여합니다. 한 연구에서는 CoQ10이 주름을 줄이고 피부 톤을 개선하는 데 도움이 된다는 결과가 발표되었습니다. 이러한 이유로 CoQ10은 여러 스킨케어 제품에도 자주 사용됩니다.<br/><br/> <h3>4. 소화 건강과 위산 역류 개선</h3> <br/> CoQ10은 위와 장의 기능을 돕고 소화 기관 내 세포에 에너지를 공급하여 소화 과정을 원활하게 만듭니다. CoQ10 보충이 소화불량이나 위산 역류 증상 완화에 긍정적인 영향을 줄 수 있다는 연구 결과도 있습니다. 특히, 소화 장애로 인한 불편감을 줄이는 데 도움이 될 수 있어 위장 건강을 신경 쓰는 사람들에게 추천됩니다.<br/><br/> <h3>5. 뇌 기능 지원과 인지 건강</h3> <br/> CoQ10의 항산화 효과는 뇌 세포를 보호하는 데도 유익합니다. 연구에 따르면 CoQ10이 뇌 세포의 산화 손상을 줄여 알츠하이머와 같은 신경퇴행성 질환 예방에 도움이 될 수 있다고 합니다. 또한, 일상적인 집중력과 기억력 향상에도 효과가 있는 것으로 나타났습니다.<br/><br/> <h2>효과적인 CoQ10 섭취 방법</h2> <br/> CoQ10은 지용성 비타민으로, 지방과 함께 섭취할 때 흡수율이 높아집니다. 따라서 오메가-3 같은 건강한 지방과 함께 복용하면 CoQ10의 효과를 극대화할 수 있습니다. 또한, 체내에서 자연 생성이 줄어드는 중년 이후에는 보충제를 통한 섭취가 도움이 될 수 있습니다.<br/><br/>', 'keywords': ['코엔자임 Q10', '에너지 향상', '심혈관 건강', '피로 회복', '소화 건강', '항산화 효과', '뇌 기능']}
# 이미 로그인 되어 있습니다.
# An error occurred: Message: no such element: Unable to locate element: {"method":"css selector","selector":".wrap_profile"}
#   (Session info: chrome=130.0.6723.70); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF7A8743AB5+28005]
# 	(No symbol) [0x00007FF7A86A83B0]
# 	(No symbol) [0x00007FF7A854580A]
# 	(No symbol) [0x00007FF7A8595A3E]
# 	(No symbol) [0x00007FF7A8595D2C]
# 	(No symbol) [0x00007FF7A85DEA97]
# 	(No symbol) [0x00007FF7A85BBA7F]
# 	(No symbol) [0x00007FF7A85DB8B3]
# 	(No symbol) [0x00007FF7A85BB7E3]
# 	(No symbol) [0x00007FF7A85875C8]
# 	(No symbol) [0x00007FF7A8588731]
# 	GetHandleVerifier [0x00007FF7A8A3643D+3118829]
# 	GetHandleVerifier [0x00007FF7A8A86C90+3448640]
# 	GetHandleVerifier [0x00007FF7A8A7CF0D+3408317]
# 	GetHandleVerifier [0x00007FF7A880A40B+841403]
# 	(No symbol) [0x00007FF7A86B340F]
# 	(No symbol) [0x00007FF7A86AF484]
# 	(No symbol) [0x00007FF7A86AF61D]
# 	(No symbol) [0x00007FF7A869EB79]
# 	BaseThreadInitThunk [0x00007FFCF26053E0+16]
# 	RtlUserThreadStart [0x00007FFCF302485B+43]
#
# 임시저장글 어쩌고가 나오지 않았습니다.
# {'title': '골밀도와 치아 건강을 동시에 강화하는 무화과 섭취의 효과', 'content': '<h2>무화과의 영양성분과 전반적인 건강 효과</h2><p>무화과는 필수 미네랄, 비타민, 그리고 식이섬유가 풍부하게 들어있는 과일로, 다양한 건강 효과를 제공합니다. 특히 칼슘과 마그네슘 함량이 높아 골밀도를 강화하고, 치아와 잇몸 건강에도 도움을 줄 수 있습니다. 무화과 한 개(약 50g)에는 약 17mg의 칼슘이 포함되어 있어 일상 식단에 쉽게 포함시킬 수 있는 칼슘 공급원이 됩니다.</p><br/><h3>1. 골밀도 강화 및 골다공증 예방 효과</h3><p>무화과에는 칼슘과 마그네슘뿐만 아니라 뼈 건강에 필수적인 비타민 K와 인이 함유되어 있어 뼈의 강도와 밀도를 높이는 데 기여합니다. 특히 칼슘은 뼈와 치아를 강화하는 주요 요소로, 충분한 섭취가 부족할 경우 골다공증의 위험이 증가할 수 있습니다. 연구에 따르면 칼슘과 비타민 K가 함께 작용할 때 골밀도 강화에 큰 효과가 있어, 무화과는 골다공증 예방을 위한 훌륭한 식품입니다.</p><br/><h3>2. 치아와 잇몸 건강에 미치는 긍정적 영향</h3><p>무화과의 칼슘과 마그네슘은 치아 에나멜 강화를 돕고 잇몸 염증을 예방하는 효과가 있습니다. 또한 비타민 C는 항산화 효과를 제공하여 잇몸 건강을 지원하고, 잇몸 질환을 예방할 수 있습니다. 연구에 따르면 무화과와 같은 과일에서 추출된 항산화 성분이 잇몸 염증을 억제하는 데 효과적이며, 이를 통해 구강 건강을 전반적으로 개선할 수 있습니다.</p><br/><h3>3. 장 건강을 위한 식이섬유 제공</h3><p>무화과에는 다량의 식이섬유가 포함되어 있어 소화 건강을 증진시키는 데 도움이 됩니다. 특히 변비 개선 및 장 기능 조절에 효과적이며, 장내 유익균 증식을 돕습니다. 연구에 따르면 무화과는 프리바이오틱스 역할을 하여 소화 과정을 개선하고 유익한 장내 박테리아를 늘리는 데 기여합니다.</p><br/><h3>4. 혈당 조절과 체중 관리 지원</h3><p>무화과는 혈당 지수가 낮아 급격한 혈당 상승을 방지하는 데 유리하며, 식이섬유 덕분에 포만감을 오래 유지할 수 있어 체중 관리에도 도움을 줍니다. 연구에 따르면 무화과에 함유된 칼륨은 혈당 조절에 긍정적인 역할을 하며, 이를 통해 제2형 당뇨 예방에 기여할 수 있습니다.</p><br/>', 'keywords': ['무화과', '골밀도 강화', '치아 건강', '잇몸 건강', '식이섬유', '혈당 조절', '체중 관리', '프리바이오틱스', '칼슘', '비타민 K', '비타민 C']}
# 이미 로그인 되어 있습니다.
# An error occurred: Message: no such element: Unable to locate element: {"method":"css selector","selector":".wrap_profile"}
#   (Session info: chrome=130.0.6723.70); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF7A8743AB5+28005]
# 	(No symbol) [0x00007FF7A86A83B0]
# 	(No symbol) [0x00007FF7A854580A]
# 	(No symbol) [0x00007FF7A8595A3E]
# 	(No symbol) [0x00007FF7A8595D2C]
# 	(No symbol) [0x00007FF7A85DEA97]
# 	(No symbol) [0x00007FF7A85BBA7F]
# 	(No symbol) [0x00007FF7A85DB8B3]
# 	(No symbol) [0x00007FF7A85BB7E3]
# 	(No symbol) [0x00007FF7A85875C8]
# 	(No symbol) [0x00007FF7A8588731]
# 	GetHandleVerifier [0x00007FF7A8A3643D+3118829]
# 	GetHandleVerifier [0x00007FF7A8A86C90+3448640]
# 	GetHandleVerifier [0x00007FF7A8A7CF0D+3408317]
# 	GetHandleVerifier [0x00007FF7A880A40B+841403]
# 	(No symbol) [0x00007FF7A86B340F]
# 	(No symbol) [0x00007FF7A86AF484]
# 	(No symbol) [0x00007FF7A86AF61D]
# 	(No symbol) [0x00007FF7A869EB79]
# 	BaseThreadInitThunk [0x00007FFCF26053E0+16]
# 	RtlUserThreadStart [0x00007FFCF302485B+43]
#
# 임시저장글 어쩌고가 나오지 않았습니다.
# {'title': '스트레스 완화를 위한 자율신경 조절법과 생활 속 실천 방법', 'content': '<h2>스트레스와 자율신경계의 관계</h2> <p>일상 속 스트레스는 자율신경계의 불균형을 초래하며, 이는 만성 피로, 소화 문제, 면역력 저하 등 다양한 신체적 문제로 이어질 수 있습니다. 자율신경계는 교감신경과 부교감신경으로 구성되어 있으며, 이 두 시스템의 균형이 깨지면 신체는 더욱 쉽게 스트레스를 받습니다.</p> <br/> <h3>자율신경계 균형을 돕는 생활 습관</h3> <p>자율신경계의 균형을 맞추기 위해 다음과 같은 습관을 생활에 도입할 수 있습니다.</p> <ul> <li><b>규칙적인 호흡 운동:</b> 느리고 깊은 호흡을 통해 부교감신경을 자극하여 신체를 안정시키는 데 도움이 됩니다. 매일 아침과 저녁에 5~10분 정도 호흡 운동을 반복하면 긴장을 줄일 수 있습니다.</li> <li><b>자연과의 교감:</b> 매일 산책이나 정원 활동을 통해 자연과의 교감을 가지면 부교감신경이 활성화되어 스트레스 해소에 도움을 줍니다.</li> <li><b>이완 운동:</b> 요가나 명상 등 이완 운동은 자율신경계를 안정시키고, 교감신경이 과도하게 활성화되는 것을 막아줍니다.</li> </ul> <br/> <h2>자율신경계 균형이 주는 건강 효과</h2> <p>자율신경계 균형을 통해 얻을 수 있는 건강 효과는 다양합니다.</p> <ul> <li><b>심혈관 건강 개선:</b> 스트레스 완화로 인해 심장 박동과 혈압이 안정되어 심혈관 질환 위험이 낮아집니다.</li> <li><b>소화 기능 강화:</b> 부교감신경이 활성화되면 소화 기능이 개선되어 소화불량과 위장 장애를 예방할 수 있습니다.</li> <li><b>면역력 향상:</b> 자율신경계 균형은 염증을 억제하고 면역 체계를 강화하여 감염성 질환 예방에 기여합니다.</li> </ul> <br/> <h3>자율신경계 조절을 위한 식단</h3> <p>자율신경계를 돕는 식단도 중요한 요소입니다. 자율신경계를 안정시키는 음식으로는 마그네슘이 풍부한 견과류와 어두운 잎채소, 오메가-3 지방산이 함유된 생선이 있으며, 부교감신경의 활성화를 촉진하는 데 도움이 됩니다.</p>', 'keywords': ['자율신경계', '스트레스 완화', '호흡 운동', '이완 운동', '자연과의 교감', '심혈관 건강', '면역력', '소화 기능']}
# 이미 로그인 되어 있습니다.
# An error occurred: Message: no such element: Unable to locate element: {"method":"css selector","selector":".wrap_profile"}
#   (Session info: chrome=130.0.6723.70); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF7A8743AB5+28005]
# 	(No symbol) [0x00007FF7A86A83B0]
# 	(No symbol) [0x00007FF7A854580A]
# 	(No symbol) [0x00007FF7A8595A3E]
# 	(No symbol) [0x00007FF7A8595D2C]
# 	(No symbol) [0x00007FF7A85DEA97]
# 	(No symbol) [0x00007FF7A85BBA7F]
# 	(No symbol) [0x00007FF7A85DB8B3]
# 	(No symbol) [0x00007FF7A85BB7E3]
# 	(No symbol) [0x00007FF7A85875C8]
# 	(No symbol) [0x00007FF7A8588731]
# 	GetHandleVerifier [0x00007FF7A8A3643D+3118829]
# 	GetHandleVerifier [0x00007FF7A8A86C90+3448640]
# 	GetHandleVerifier [0x00007FF7A8A7CF0D+3408317]
# 	GetHandleVerifier [0x00007FF7A880A40B+841403]
# 	(No symbol) [0x00007FF7A86B340F]
# 	(No symbol) [0x00007FF7A86AF484]
# 	(No symbol) [0x00007FF7A86AF61D]
# 	(No symbol) [0x00007FF7A869EB79]
# 	BaseThreadInitThunk [0x00007FFCF26053E0+16]
# 	RtlUserThreadStart [0x00007FFCF302485B+43]
#
# 임시저장글 어쩌고가 나오지 않았습니다.
# {'title': '눈 건강과 집중력 개선을 위한 라즈베리키톤의 효능', 'content': '<h2>눈 건강과 집중력을 동시에 개선하는 라즈베리키톤</h2><br/>라즈베리키톤은 주로 체지방 감소와 관련된 성분으로 잘 알려져 있지만, 그 외에도 눈 건강과 인지 기능 향상에 도움을 줄 수 있습니다. 특히 눈의 피로를 완화하고, 집중력과 기억력을 유지하는 데 유익한 여러 기능을 제공합니다.<br/><br/><h3>1. 강력한 항산화 효과로 눈의 산화 스트레스 완화</h3><br/>라즈베리키톤은 항산화 성분이 풍부해 눈 주변 세포의 산화 손상을 막아주는 역할을 합니다. 이는 특히 디지털 기기 사용이 많은 현대인에게 중요한데, 블루라이트로 인한 눈의 피로와 손상을 줄여 눈의 피로도를 감소시키고 시력 보호에 도움이 됩니다.<br/><br/><h3>2. 시력 보호와 노화 방지</h3><br/>라즈베리키톤은 시력을 보호하고 눈 조직의 세포 노화를 지연시키는 데 도움을 줄 수 있습니다. 이는 안구 건조증이나 눈의 노화 문제를 예방하고, 나이가 들어감에 따라 발생할 수 있는 시력 저하를 방지하는 데 유효합니다.<br/><br/><h3>3. 집중력 향상 및 인지 기능 보호</h3><br/>라즈베리키톤은 중추신경계에 긍정적인 영향을 미칠 수 있는 성분으로, 집중력과 기억력 유지에 도움을 줄 수 있습니다. 특히 스트레스 상황에서 신경계를 보호해 인지 기능을 보호하며, 기억력을 강화해 일상 생활에서 주의력과 학습 능력을 증진하는 데 기여합니다.<br/><br/><h3>4. 눈과 뇌 건강을 위해 라즈베리키톤 섭취 방법</h3><br/>라즈베리키톤은 일반적으로 보충제 형태로 쉽게 섭취할 수 있으며, 라즈베리 자체를 과일로 섭취해도 일부 효과를 누릴 수 있습니다. 하루 100-200mg 정도의 라즈베리키톤 보충제를 꾸준히 복용하면 눈과 뇌의 건강에 유익할 수 있습니다.<br/><br/><b>주의사항:</b> 라즈베리키톤 보충제는 임산부와 특정 질환이 있는 경우 섭취 전 전문가와 상담하는 것이 좋습니다.', 'keywords': ['라즈베리키톤', '눈 건강', '집중력 향상', '항산화 효과', '시력 보호', '인지 기능']}
# 이미 로그인 되어 있습니다.
# An error occurred: Message: no such element: Unable to locate element: {"method":"css selector","selector":".wrap_profile"}
#   (Session info: chrome=130.0.6723.70); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF7A8743AB5+28005]
# 	(No symbol) [0x00007FF7A86A83B0]
# 	(No symbol) [0x00007FF7A854580A]
# 	(No symbol) [0x00007FF7A8595A3E]
# 	(No symbol) [0x00007FF7A8595D2C]
# 	(No symbol) [0x00007FF7A85DEA97]
# 	(No symbol) [0x00007FF7A85BBA7F]
# 	(No symbol) [0x00007FF7A85DB8B3]
# 	(No symbol) [0x00007FF7A85BB7E3]
# 	(No symbol) [0x00007FF7A85875C8]
# 	(No symbol) [0x00007FF7A8588731]
# 	GetHandleVerifier [0x00007FF7A8A3643D+3118829]
# 	GetHandleVerifier [0x00007FF7A8A86C90+3448640]
# 	GetHandleVerifier [0x00007FF7A8A7CF0D+3408317]
# 	GetHandleVerifier [0x00007FF7A880A40B+841403]
# 	(No symbol) [0x00007FF7A86B340F]
# 	(No symbol) [0x00007FF7A86AF484]
# 	(No symbol) [0x00007FF7A86AF61D]
# 	(No symbol) [0x00007FF7A869EB79]
# 	BaseThreadInitThunk [0x00007FFCF26053E0+16]
# 	RtlUserThreadStart [0x00007FFCF302485B+43]
#
# 임시저장글 어쩌고가 나오지 않았습니다.

# %%
import json
import time
import requests
import os

from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver import ActionChains
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.alert import Alert
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import TimeoutException, NoSuchElementException
from webdriver_manager.chrome import ChromeDriverManager
import undetected_chromedriver as uc
from undetected_chromedriver.options import ChromeOptions


# 만약에 ChromeDriverManager를 install 해야 할 상황이 오면 아래의 옵션으로 인스톨 한번 해준 후 다시 주석처리 해주기
options = ChromeOptions()
options.add_argument(r"user-data-dir=C:\\selenium_data\\Chrome")
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)

driver.get("https://chatgpt.com/g/g-GB6qPTSIt-yeogsi-sseol-blog-json")

# %%
driver = uc.Chrome(service=Service(ChromeDriverManager().install()), user_data_dir='C:\\selenium_data\\Chrome', port=54805, disable_logging=True, detach=True, excludeSwitches=["enable-logging"])
driver.get("https://www.google.com")

# %%
import time
round(time.time())
# Out:
# 1728427092
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import re

def replace_markdown_bold_with_html(text):
    # 정규식 패턴: **로 감싸진 문자열 찾기
    pattern = r"\*\*(.*?)\*\*"
    
    # 매치된 문자열을 <b> </b>로 감싸는 함수
    def replace_with_bold(match):
        return f"<b>{match.group(1)}</b>"
    
    # 전체 텍스트에서 패턴에 매치되는 모든 부분을 찾아 replace_with_bold 함수로 변환
    return re.sub(pattern, replace_with_bold, text)

# 예제 사용
text = "This is an **example** text with **bold** words."
converted_text = replace_markdown_bold_with_html(text)
print(converted_text)
# Out:
# This is an <b>example</b> text with <b>bold</b> words.

# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

# MongoDB 연결
uri = "mongodb+srv://admin:admin12341234@cluster0.3e37l.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"
# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

db = client['tistory']

# 'posts' 컬렉션을 지정
postsDB = db['posts']

print("Connected to MongoDB")

# DB에 저장하기
postsDB.insert_one({"title":"고대 페르시아 제국의 영광과 추락: 다리우스와 크세르크세스의 비밀", "category": "category-item-1201184", "created_at": time.time()})
# Out:
# Connected to MongoDB
# InsertOneResult(ObjectId('67061a4dc6626093864af4b4'), acknowledged=True)

# %%
import json
import time
import requests
import os
import re
import pyperclip

from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver import ActionChains
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.alert import Alert
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import TimeoutException, NoSuchElementException

from webdriver_manager.chrome import ChromeDriverManager
import undetected_chromedriver as uc
from undetected_chromedriver.options import ChromeOptions

# MongoDB 연결
uri = "mongodb+srv://admin:admin12341234@cluster0.3e37l.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"
# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

db = client['tistory']

# 'posts' 컬렉션을 지정
postsDB = db['posts']

print("Connected to MongoDB")

# 만약에 ChromeDriverManager를 install 해야 할 상황이 오면 아래의 옵션으로 인스톨 한번 해준 후 다시 주석처리 해주기
# options = ChromeOptions()
# options.add_argument(r"user-data-dir=C:\\selenium_data\\Chrome")
# driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)

# 역사 썰
history_story = ['category-item-1201184', 'https://chatgpt.com/g/g-GB6qPTSIt-yeogsa-sseol-blog-json']
science_story = ['category-item-1201410', 'https://chatgpt.com/g/g-G6PYOE1TE-gwahag-sseol-blog-json']

posting = history_story

driver = uc.Chrome(service=Service(ChromeDriverManager().install()), user_data_dir='C:\\selenium_data\\Chrome', port=54806, disable_logging=True, detach=True, excludeSwitches=["enable-logging"])
driver.get("https://www.google.com")

def write_tistory_post(title, content, keywords):
    def get_recent_file_path():
        files_path = r"C:\Users\Jinyo3090\Downloads"

        file_name_and_time_lst = []
        # 해당 경로에 있는 파일들의 생성시간을 함께 리스트로 넣어줌. 
        for f_name in os.listdir(f"{files_path}"):
            written_time = os.path.getctime(f"{files_path}\\{f_name}")
            file_name_and_time_lst.append((f_name, written_time))
        # 생성시간 역순으로 정렬하고, 
        sorted_file_lst = sorted(file_name_and_time_lst, key=lambda x: x[1], reverse=True)
        # 가장 앞에 이는 놈을 넣어준다.
        recent_file = sorted_file_lst[0]
        recent_file_name = recent_file[0]

        return f"{files_path}\\{recent_file_name}"
    # tistory_driver = uc.Chrome(user_data_dir='C:\\selenium_data\\Chrome', port=54806)
    tistory_driver = driver
    # 셀레니움으로 티스토리 포스팅 url로 넘어가기
    tistory_driver.implicitly_wait(4)
    tistory_driver.get("https://dropdrop.tistory.com/manage/posts")
    tistory_driver.implicitly_wait(10)
    
    # 로그인 창으로 넘어갈 경우 로그인하기
    try :
        login_button = tistory_driver.find_element(By.CLASS_NAME, "btn_login")
        ActionChains(tistory_driver).click(login_button).perform()
        tistory_driver.implicitly_wait(10)

        id_input = tistory_driver.find_element(By.NAME, "loginId")
        pw_input = tistory_driver.find_element(By.NAME, "password")

        ActionChains(tistory_driver).send_keys_to_element(id_input, "solomoj94@naver.com").perform()
        tistory_driver.implicitly_wait(1)
        ActionChains(tistory_driver).send_keys_to_element(pw_input, "skfrosla131").perform()
        tistory_driver.implicitly_wait(1)

        login_button = tistory_driver.find_element(By.CLASS_NAME, "submit")
        ActionChains(tistory_driver).click(login_button).perform()
        tistory_driver.implicitly_wait(4)
    except NoSuchElementException as e :
        print("이미 로그인 되어 있습니다.")
        # 로그인 되어 있는 경우에는 계정 버튼을 눌러서 들어가기
        try :
            account_button = tistory_driver.find_element(By.CLASS_NAME, "wrap_profile")
            ActionChains(tistory_driver).click(account_button).perform()
            tistory_driver.implicitly_wait(4)
        except Exception as e:
            print(f"An error occurred: {e}")
    except Exception as e:
        print(f"An error occurred: {e}")

    # 글 쓰기 버튼 클릭하기
    write_button = tistory_driver.find_element(By.CLASS_NAME, "link_write")
    ActionChains(tistory_driver).click(write_button).perform()
    tistory_driver.implicitly_wait(10)

    # 혹시나 임시저장글 어쩌고가 나올 때를 대비해서
    try :
        alert_present = WebDriverWait(tistory_driver, 5).until(EC.alert_is_present())
        if alert_present:
            tistory_alert = Alert(tistory_driver)
            tistory_alert.dismiss()
            tistory_driver.implicitly_wait(1)
    except TimeoutException as e :
        print("임시저장글 어쩌고가 나오지 않았습니다.")
    except Exception as e:
        print(f"An error occurred: {e}")

    # 글 카테고리 선택하기
    category_button = tistory_driver.find_element(By.ID, "category-btn")
    ActionChains(tistory_driver).click(category_button).perform()
    tistory_driver.implicitly_wait(10)
    # 역사시간 순삭 카테고리
    science_category_list_btn = tistory_driver.find_element(By.ID, posting[0])
    ActionChains(tistory_driver).click(science_category_list_btn).perform()
    tistory_driver.implicitly_wait(1)

    # 글 입력 형식 바꾸기
    category_button = tistory_driver.find_element(By.ID, "editor-mode-layer-btn-open")
    ActionChains(tistory_driver).click(category_button).perform()
    tistory_driver.implicitly_wait(10)
    # HTML 형식으로 바꾸기
    science_category_list_btn = tistory_driver.find_element(By.ID, 'editor-mode-html')
    ActionChains(tistory_driver).click(science_category_list_btn).perform()
    tistory_driver.implicitly_wait(1)
    # 경고창이 뜨면 확인 버튼 누르기
    alert_present = WebDriverWait(tistory_driver, 5).until(EC.alert_is_present())
    if alert_present:
        tistory_alert = Alert(tistory_driver)
        tistory_alert.accept()
        tistory_driver.implicitly_wait(1)

    #글 제목 입력하기
    title_input = tistory_driver.find_element(By.CLASS_NAME, "textarea_tit")
    ActionChains(tistory_driver).send_keys_to_element(title_input, title).perform()
    tistory_driver.implicitly_wait(1)


    #사진 업로드하기
    attach_layer_button = tistory_driver.find_element(By.ID, "attach-layer-btn")
    ActionChains(tistory_driver).click(attach_layer_button).perform()
    tistory_driver.implicitly_wait(1)
    image_input = tistory_driver.find_element(By.ID, "attach-image")
    image_input.send_keys(get_recent_file_path())
    tistory_driver.implicitly_wait(1)
    time.sleep(3)
    
    #글 내용 입력하기 (HTML)
    #클립보드에 content 복사
    pyperclip.copy(content)
    content_input = tistory_driver.find_element(By.CLASS_NAME, "mce-edit-area")
    ActionChains(tistory_driver).click(content_input).perform()
    ActionChains(tistory_driver).key_down(Keys.CONTROL).send_keys('v').key_up(Keys.CONTROL).perform()
    tistory_driver.implicitly_wait(10)

    #태그 내용 입력하기
    tag_input = tistory_driver.find_element(By.ID, "tagText")
    ActionChains(tistory_driver).send_keys_to_element(tag_input, keywords).perform()
    tistory_driver.implicitly_wait(1)
    

    
    # 글 입력 형식 바꾸기
    category_button = tistory_driver.find_element(By.XPATH, "//*[@id='html-editor-container']/div[1]/div/div/div/div/div/div[5]/div/div/button")
    ActionChains(tistory_driver).click(category_button).perform()
    tistory_driver.implicitly_wait(10)

    # 기본 형식으로 바꾸기 (대표 이미지 자동 설정을 위해)
    science_category_list_btn = tistory_driver.find_element(By.ID, 'editor-mode-kakao-tistory')
    ActionChains(tistory_driver).click(science_category_list_btn).perform()
    tistory_driver.implicitly_wait(1)
    # 경고창이 뜨면 확인 버튼 누르기
    alert_present = WebDriverWait(tistory_driver, 5).until(EC.alert_is_present())
    if alert_present:
        tistory_alert = Alert(tistory_driver)
        tistory_alert.accept()
        tistory_driver.implicitly_wait(1)
        
    time.sleep(3)

    #완료 버튼 누르기
    publish_layer_button = tistory_driver.find_element(By.ID, "publish-layer-btn")
    ActionChains(tistory_driver).click(publish_layer_button).perform()
    tistory_driver.implicitly_wait(1)

    # DB에 저장하기
    postsDB.insert_one({"title":title, "category": posting[0], "created_at": time.time()})
    # 공개 버튼 누르기 (티스토리 기본 설정에서 변경 가능)
    # public_button = tistory_driver.find_element(By.XPATH, "//*[@id='editor-root']/div[5]/div/div/div/form/fieldset/div[2]/div/dl[1]/dd/div[1]")
    # ActionChains(tistory_driver).click(public_button).perform()
    # tistory_driver.implicitly_wait(1)
    # public_button = tistory_driver.find_element(By.XPATH, "//*[@id='editor-root']/div[5]/div/div/div/form/fieldset/div[2]/div/dl[1]/dd/div[1]")
    # ActionChains(tistory_driver).click(public_button).perform()
    # tistory_driver.implicitly_wait(1)

    # 대표이미지 설정하기 안됨..
    # image_input = tistory_driver.find_element(By.CLASS_NAME, "inp_g")
    # image_input.send_keys(get_recent_file_path())
    # tistory_driver.implicitly_wait(2)

    # #발행 버튼 누르기
    publish_button = tistory_driver.find_element(By.ID, "publish-btn")
    ActionChains(tistory_driver).click(publish_button).perform()
    tistory_driver.implicitly_wait(1)
    

def main_process():
    write_tistory_post("제목", "내용", ['keywords'])

for i in range(1):
    main_process()
# Out:
# Connected to MongoDB
# ---------------------------------------------------------------------------
# InvalidArgumentException                  Traceback (most recent call last)
# Cell In[14], line 224
#     221     write_tistory_post("제목", "내용", ['keywords'])
#     223 for i in range(1):
# --> 224     main_process()
#
# Cell In[14], line 221, in main_process()
#     220 def main_process():
# --> 221     write_tistory_post("제목", "내용", ['keywords'])
#
# Cell In[14], line 171, in write_tistory_post(title, content, keywords)
#     169 #태그 내용 입력하기
#     170 tag_input = tistory_driver.find_element(By.ID, "tagText")
# --> 171 ActionChains(tistory_driver).send_keys_to_element(tag_input, keywords).perform()
#     172 tistory_driver.implicitly_wait(1)
#     176 # 글 입력 형식 바꾸기
#
# File c:\Python312\Lib\site-packages\selenium\webdriver\common\action_chains.py:94, in ActionChains.perform(self)
#      92 def perform(self) -> None:
#      93     """Performs all stored actions."""
# ---> 94     self.w3c_actions.perform()
#
# File c:\Python312\Lib\site-packages\selenium\webdriver\common\actions\action_builder.py:96, in ActionBuilder.perform(self)
#      94         enc["actions"].append(encoded)
#      95         device.actions = []
# ---> 96 self.driver.execute(Command.W3C_ACTIONS, enc)
#
# File c:\Python312\Lib\site-packages\selenium\webdriver\remote\webdriver.py:354, in WebDriver.execute(self, driver_command, params)
#     352 response = self.command_executor.execute(driver_command, params)
#     353 if response:
# --> 354     self.error_handler.check_response(response)
#     355     response["value"] = self._unwrap_value(response.get("value", None))
#     356     return response
#
# File c:\Python312\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# InvalidArgumentException: Message: invalid argument
# from invalid argument: 'value' must be a single Unicode code point
#   (Session info: chrome=129.0.6668.90)
# Stacktrace:
# 	GetHandleVerifier [0x00E270E3+25587]
# 	(No symbol) [0x00DBA284]
# 	(No symbol) [0x00CB2113]
# 	(No symbol) [0x00D3AC91]
# 	(No symbol) [0x00D3BEFD]
# 	(No symbol) [0x00D1AB9C]
# 	(No symbol) [0x00D35370]
# 	(No symbol) [0x00D1A936]
# 	(No symbol) [0x00CEBA73]
# 	(No symbol) [0x00CEC4CD]
# 	GetHandleVerifier [0x01104C23+3030835]
# 	GetHandleVerifier [0x01156B59+3366505]
# 	GetHandleVerifier [0x00EB9592+624802]
# 	GetHandleVerifier [0x00EC0E0C+655644]
# 	(No symbol) [0x00DC2C3D]
# 	(No symbol) [0x00DBFD08]
# 	(No symbol) [0x00DBFEA5]
# 	(No symbol) [0x00DB22D6]
# 	BaseThreadInitThunk [0x755D6839+25]
# 	RtlGetFullPathName_UEx [0x76F9906F+1215]
# 	RtlGetFullPathName_UEx [0x76F9903D+1165]

# %%
# %pip install pyperclip
# Out:
# Collecting pyperclip
#   Downloading pyperclip-1.9.0.tar.gz (20 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Building wheels for collected packages: pyperclip
#   Building wheel for pyperclip (pyproject.toml): started
#   Building wheel for pyperclip (pyproject.toml): finished with status 'done'
#   Created wheel for pyperclip: filename=pyperclip-1.9.0-py3-none-any.whl size=11019 sha256=5be52c91c3a004cab271c1c177216e30945193b2fe56f312f72007236877360a
#   Stored in directory: c:\users\jinyo3090\appdata\local\pip\cache\wheels\e0\e8\fc\8ab8aa326e33bc066ccd5f3ca9646eab4299881af933f94f09
# Successfully built pyperclip
# Installing collected packages: pyperclip
# Successfully installed pyperclip-1.9.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
